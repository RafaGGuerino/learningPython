# %%
import requests

url = 'https://viacep.com.br/ws/69010000/json/'

resposta = requests.get(url)

dados = resposta.json()

for i in dados:
    print(f'{i}: {dados[i]}')
# Out:
# cep: 69010-000
# logradouro: Avenida Eduardo Ribeiro
# complemento: de 301/302 a 630/631
# unidade:
# bairro: Centro
# localidade: Manaus
# uf: AM
# estado: Amazonas
# regiao: Norte
# ibge: 1302603
# gia:
# ddd: 92
# siafi: 0255
